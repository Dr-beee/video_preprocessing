# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
    # for filename in filenames:
    #     print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input
# /kaggle/input/my_temp
# /kaggle/input/my_temp/pytorch
# /kaggle/input/my_temp/pytorch/default
# /kaggle/input/my_temp/pytorch/default/1
# /kaggle/input/my-temp
# /kaggle/input/pm-71595720-at-11-25-2024-13-31-01

# %%
from ultralytics import YOLO
from pytubefix import YouTube  # pytube-fix 사용
import cv2

youtube_url = 'https://www.youtube.com/watch?v=IaLPsDV9AbQ'
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
def download_youtube_video(url, output_path="/kaggle/working/output"):
    yt = YouTube(url)
    video_stream = yt.streams.filter(file_extension="mp4", res="720p").first()
    if not video_stream:
        video_stream = yt.streams.get_highest_resolution()
    os.makedirs(output_path, exist_ok=True)
    video_path = os.path.join(output_path, yt.title + ".mp4")
    video_stream.download(output_path)
    return video_path


if not os.path.exists('/kaggle/input/my-temp/sample_video.mp4'):
    downloaded_video = download_youtube_video(youtube_url)

# %%
# !rm /kaggle/working/output/result_sample_video.mp4

# %%
from typing import Tuple
from datetime import datetime

# Reference : https://gist.github.com/IdeaKing/11cf5e146d23c5bb219ba3508cca89ec
def resize_with_pad(image: np.array, 
                    new_shape: Tuple[int, int], 
                    padding_color: Tuple[int] = (0, 0, 0)) -> np.array:
    """Maintains aspect ratio and resizes with padding.
    Params:
        image: Image to be resized.
        new_shape: Expected (width, height) of new image.
        padding_color: Tuple in BGR of padding color
    Returns:
        image: Resized image with padding
    """
    original_shape = (image.shape[1], image.shape[0])
    ratio = float(max(new_shape))/max(original_shape)
    new_size = tuple([int(x*ratio) for x in original_shape])
    image = cv2.resize(image, new_size)
    delta_w = new_shape[0] - new_size[0]
    delta_h = new_shape[1] - new_size[1]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=padding_color)
    return image


def process_video_with_yolo(video_path, model_path="/kaggle/input/my_temp/pytorch/default/1/best.pt", output_path="/kaggle/working/output"):
    model = YOLO(model_path)  # YOLO 모델 로드
    cap = cv2.VideoCapture(video_path)
    os.makedirs(output_path, exist_ok=True)

    # 비디오 저장 설정
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    print(f'{width} {height} {fps}')
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # MP4 코덱 설정
    out_path = os.path.join(output_path, "result_" + os.path.basename(video_path))
    out = cv2.VideoWriter(out_path, fourcc, fps, (640, 640))
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 프레임 리사이즈 (640x640)
        start_time = datetime.now()
        # resized_frame = cv2.resize(frame, (640, 640))
        resized_frame = resize_with_pad(frame, new_shape=[640, 640],padding_color= [0, 0, 0])
        end_time = datetime.now()
        elapsed_time = end_time - start_time
        print(f'[Info] elapsed_time 4 resize={elapsed_time.total_seconds()}s')
        
        # YOLO 추론
        results = model(resized_frame)
        
        # 결과 시각화
        annotated_frame = results[0].plot()  # 탐지 결과를 프레임에 그리기
        out.write(annotated_frame)  # MP4에 저장

    cap.release()
    out.release()
    print(f"MP4 저장 완료: {out_path}")
    return out_path


if not os.path.exists('/kaggle/input/my-temp/sample_video.mp4'):
    result_video = process_video_with_yolo(video_path='/kaggle/working/output/꿀벌 날개가 이상해요... 진드기 피해가 심각하네요.  꿀벌아 미안해.mp4')    
else:
    result_video = process_video_with_yolo(video_path='/kaggle/input/my-temp/sample_video.mp4')
# Out:
# 1280 720 30
# [Info] elapsed_time 4 resize=0.006873s
#
# 0: 640x640 16 정상s, 7.6ms
# Speed: 7.1ms preprocess, 7.6ms inference, 244.6ms postprocess per image at shape (1, 3, 640, 640)
# Downloading https://ultralytics.com/assets/Arial.Unicode.ttf
 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00063s
#
# 0: 640x640 13 정상s, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000676s
#
# 0: 640x640 14 정상s, 2 날개불구바이러스감염증s, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00068s
#
# 0: 640x640 14 정상s, 2 날개불구바이러스감염증s, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000656s
#
# 0: 640x640 13 정상s, 1 날개불구바이러스감염증, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000746s
#
# 0: 640x640 13 정상s, 1 날개불구바이러스감염증, 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000764s
#
# 0: 640x640 13 정상s, 3 날개불구바이러스감염증s, 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000718s
#
# 0: 640x640 13 정상s, 3 날개불구바이러스감염증s, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000739s
#
# 0: 640x640 12 정상s, 2 날개불구바이러스감염증s, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000803s
#
# 0: 640x640 12 정상s, 2 날개불구바이러스감염증s, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000723s
#
# 0: 640x640 12 정상s, 2 날개불구바이러스감염증s, 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000803s
#
# 0: 640x640 12 정상s, 2 날개불구바이러스감염증s, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000797s
#
# 0: 640x640 13 정상s, 2 날개불구바이러스감염증s, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000719s
#
# 0: 640x640 13 정상s, 2 날개불구바이러스감염증s, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000698s
#
# 0: 640x640 11 정상s, 1 날개불구바이러스감염증, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000695s
#
# 0: 640x640 11 정상s, 1 날개불구바이러스감염증, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000612s
#
# 0: 640x640 12 정상s, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000738s
#
# 0: 640x640 12 정상s, 6.3ms
# Speed: 2.7ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000658s
#
# 0: 640x640 11 정상s, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000599s
#
# 0: 640x640 11 정상s, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000627s
#
# 0: 640x640 12 정상s, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000661s
#
# 0: 640x640 12 정상s, 7.5ms
# Speed: 1.7ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000618s
#
# 0: 640x640 13 정상s, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000597s
#
# 0: 640x640 13 정상s, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000625s
#
# 0: 640x640 13 정상s, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000629s
#
# 0: 640x640 13 정상s, 6.3ms
# Speed: 2.5ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000601s
#
# 0: 640x640 13 정상s, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000637s
#
# 0: 640x640 12 정상s, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000664s
#
# 0: 640x640 13 정상s, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000747s
#
# 0: 640x640 13 정상s, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000724s
#
# 0: 640x640 12 정상s, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000729s
#
# 0: 640x640 12 정상s, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00074s
#
# 0: 640x640 13 정상s, 7.5ms
# Speed: 2.3ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000722s
#
# 0: 640x640 13 정상s, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000728s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 8.2ms
# Speed: 1.8ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.0008s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000868s
#
# 0: 640x640 14 정상s, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000834s
#
# 0: 640x640 14 정상s, 7.2ms
# Speed: 2.6ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000769s
#
# 0: 640x640 14 정상s, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000693s
#
# 0: 640x640 14 정상s, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000716s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000676s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000719s
#
# 0: 640x640 12 정상s, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000718s
#
# 0: 640x640 12 정상s, 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000713s
#
# 0: 640x640 11 정상s, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000693s
#
# 0: 640x640 11 정상s, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000716s
#
# 0: 640x640 11 정상s, 7.3ms
# Speed: 1.9ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000702s
#
# 0: 640x640 11 정상s, 7.2ms
# Speed: 1.9ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000678s
#
# 0: 640x640 12 정상s, 2 날개불구바이러스감염증s, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000662s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000624s
#
# 0: 640x640 10 정상s, 1 날개불구바이러스감염증, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000742s
#
# 0: 640x640 10 정상s, 1 날개불구바이러스감염증, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000674s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000738s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000621s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000626s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000603s
#
# 0: 640x640 10 정상s, 1 날개불구바이러스감염증, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000774s
#
# 0: 640x640 10 정상s, 1 날개불구바이러스감염증, 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000709s
#
# 0: 640x640 11 정상s, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000686s
#
# 0: 640x640 11 정상s, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000781s
#
# 0: 640x640 12 정상s, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000762s
#
# 0: 640x640 12 정상s, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000638s
#
# 0: 640x640 11 정상s, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000683s
#
# 0: 640x640 11 정상s, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000768s
#
# 0: 640x640 10 정상s, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000853s
#
# 0: 640x640 10 정상s, 7.6ms
# Speed: 2.3ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00078s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000724s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000792s
#
# 0: 640x640 11 정상s, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000723s
#
# 0: 640x640 11 정상s, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000771s
#
# 0: 640x640 11 정상s, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000661s
#
# 0: 640x640 11 정상s, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000699s
#
# 0: 640x640 12 정상s, 7.5ms
# Speed: 2.1ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000684s
#
# 0: 640x640 12 정상s, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00072s
#
# 0: 640x640 11 정상s, 1 날개불구바이러스감염증, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000676s
#
# 0: 640x640 11 정상s, 1 날개불구바이러스감염증, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000715s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000823s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000628s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000716s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000757s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000701s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000694s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000699s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000729s
#
# 0: 640x640 11 정상s, 4 날개불구바이러스감염증s, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000868s
#
# 0: 640x640 11 정상s, 4 날개불구바이러스감염증s, 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00071s
#
# 0: 640x640 10 정상s, 4 날개불구바이러스감염증s, 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000631s
#
# 0: 640x640 10 정상s, 4 날개불구바이러스감염증s, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00068s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000734s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000718s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000622s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000686s
#
# 0: 640x640 11 정상s, 4 날개불구바이러스감염증s, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000665s
#
# 0: 640x640 11 정상s, 4 날개불구바이러스감염증s, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000655s
#
# 0: 640x640 12 정상s, 4 날개불구바이러스감염증s, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000602s
#
# 0: 640x640 12 정상s, 4 날개불구바이러스감염증s, 6.3ms
# Speed: 2.1ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000633s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00076s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000672s
#
# 0: 640x640 11 정상s, 1 날개불구바이러스감염증, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000631s
#
# 0: 640x640 11 정상s, 1 날개불구바이러스감염증, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00069s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000714s
#
# 0: 640x640 11 정상s, 1 날개불구바이러스감염증, 6.1ms
# Speed: 1.7ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000709s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000659s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000717s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000681s
#
# 0: 640x640 11 정상s, 3 날개불구바이러스감염증s, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000721s
#
# 0: 640x640 9 정상s, 4 날개불구바이러스감염증s, 6.9ms
# Speed: 1.6ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000665s
#
# 0: 640x640 9 정상s, 4 날개불구바이러스감염증s, 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000701s
#
# 0: 640x640 11 정상s, 1 날개불구바이러스감염증, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000663s
#
# 0: 640x640 11 정상s, 1 날개불구바이러스감염증, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000702s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00067s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000695s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00066s
#
# 0: 640x640 12 정상s, 1 날개불구바이러스감염증, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.0007s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000624s
#
# 0: 640x640 11 정상s, 2 날개불구바이러스감염증s, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000692s
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000674s
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000644s
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000669s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000657s
#
# 0: 640x640 (no detections), 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00068s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000759s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000586s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00067s
#
# 0: 640x640 (no detections), 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000633s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000648s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000711s
#
# 0: 640x640 (no detections), 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000663s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000622s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000595s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000609s
#
# 0: 640x640 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00067s
#
# 0: 640x640 (no detections), 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000621s
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000652s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000627s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000654s
#
# 0: 640x640 (no detections), 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000634s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000616s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000644s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000669s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000705s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00064s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000723s
#
# 0: 640x640 (no detections), 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000705s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00073s
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000659s
#
# 0: 640x640 (no detections), 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000695s
#
# 0: 640x640 (no detections), 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000685s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000679s
#
# 0: 640x640 (no detections), 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000605s
#
# 0: 640x640 (no detections), 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00067s
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000712s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00072s
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000706s
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000694s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000771s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000713s
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000742s
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000743s
#
# 0: 640x640 (no detections), 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000769s
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000679s
#
# 0: 640x640 (no detections), 8.4ms
# Speed: 1.9ms preprocess, 8.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000711s
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000707s
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000734s
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000828s
#
# 0: 640x640 (no detections), 11.2ms
# Speed: 2.3ms preprocess, 11.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000772s
#
# 0: 640x640 (no detections), 13.2ms
# Speed: 2.5ms preprocess, 13.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000774s
#
# 0: 640x640 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.001301s
#
# 0: 640x640 (no detections), 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000711s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000744s
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000695s
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000824s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000613s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00062s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000705s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000613s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000681s
#
# 0: 640x640 (no detections), 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000659s
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000628s
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000631s
#
# 0: 640x640 (no detections), 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000621s
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000645s
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000628s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000684s
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000728s
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000697s
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000694s
#
# 0: 640x640 34 정상s, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000649s
#
# 0: 640x640 34 정상s, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000762s
#
# 0: 640x640 32 정상s, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000761s
#
# 0: 640x640 32 정상s, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000758s
#
# 0: 640x640 31 정상s, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000648s
#
# 0: 640x640 33 정상s, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.00062s
#
# 0: 640x640 34 정상s, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000611s
#
# 0: 640x640 33 정상s, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000664s
#
# 0: 640x640 34 정상s, 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000722s
#
# 0: 640x640 34 정상s, 7.8ms
# Speed: 2.3ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.000746s
#
# 0: 640x640 32 정상s, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [Info] elapsed_time 4 resize=0.